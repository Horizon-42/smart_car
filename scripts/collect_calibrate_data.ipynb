# %%
from jetcam.csi_camera import CSICamera
# from jetcam.usb_camera import USBCamera

camera = CSICamera(width=640, height=480)

camera.running = True

# %%
# unobserve all callbacks from camera in case we are running this cell for second time
camera.unobserve_all()

# %%
import shutil

shutil.rmtree("pics")

# %%
import ipywidgets
import traitlets

from IPython.display import display
from jetcam.utils import bgr8_to_jpeg
from jupyter_clickable_image_widget import ClickableImageWidget

import cv2
import os

camera_widget = ClickableImageWidget(width=camera.width, height=camera.height)
snapshot_widget = ipywidgets.Image(width=camera.width, height=camera.height)
traitlets.dlink((camera, 'value'), (camera_widget, 'value'), transform=bgr8_to_jpeg)


index = 0

os.makedirs("pics", exist_ok=True)

def save_snapshot(_, content, msg):
    global index
    if content['event'] == 'click':
        # display saved snapshot
        snapshot = camera.value.copy()
        cv2.imwrite(f"pics/pic{index}.jpg", snapshot)
        index+=1
        snapshot_widget.value = bgr8_to_jpeg(snapshot)
        
camera_widget.on_msg(save_snapshot)

data_collection_widget = ipywidgets.HBox([
    camera_widget,
    snapshot_widget
])

display(data_collection_widget)
# Out:
# HBox(children=(ClickableImageWidget(value=b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x…

# %%
import threading
import time

# --- auto capture section ---
def auto_capture():
    os.makedirs("road", exist_ok=True)
    total_time = 2 * 60  # 2 minutes
    interval = 1         # 1 seconds
    count = total_time // interval
    print(f"Starting auto capture: {count} images every {interval} seconds...")
    
    for i in range(count):
        frame = camera.value.copy()
        path = f"road/road_{i:03d}.jpg"
        cv2.imwrite(path, frame)
        print(f"[{i+1}/{count}] Saved {path}")
        time.sleep(interval)
    
    print("Auto capture completed.")

# Run auto capture in a background thread so it won’t block the notebook UI
thread = threading.Thread(target=auto_capture, daemon=True)
thread.start()
# Out:
# Starting auto capture: 120 images every 1 seconds...
# [1/120] Saved road/road_000.jpg
# [2/120] Saved road/road_001.jpg
# [3/120] Saved road/road_002.jpg
# [4/120] Saved road/road_003.jpg
# [5/120] Saved road/road_004.jpg
# [6/120] Saved road/road_005.jpg
# [7/120] Saved road/road_006.jpg
# [8/120] Saved road/road_007.jpg
# [9/120] Saved road/road_008.jpg
# [10/120] Saved road/road_009.jpg
# [11/120] Saved road/road_010.jpg
# [12/120] Saved road/road_011.jpg
# [13/120] Saved road/road_012.jpg
# [14/120] Saved road/road_013.jpg
# [15/120] Saved road/road_014.jpg
# [16/120] Saved road/road_015.jpg
# [17/120] Saved road/road_016.jpg
# [18/120] Saved road/road_017.jpg
# [19/120] Saved road/road_018.jpg
# [20/120] Saved road/road_019.jpg
# [21/120] Saved road/road_020.jpg
# [22/120] Saved road/road_021.jpg
# [23/120] Saved road/road_022.jpg
# [24/120] Saved road/road_023.jpg
# [25/120] Saved road/road_024.jpg
# [26/120] Saved road/road_025.jpg
# [27/120] Saved road/road_026.jpg
# [28/120] Saved road/road_027.jpg
# [29/120] Saved road/road_028.jpg
# [30/120] Saved road/road_029.jpg
# [31/120] Saved road/road_030.jpg
# [32/120] Saved road/road_031.jpg
# [33/120] Saved road/road_032.jpg
# [34/120] Saved road/road_033.jpg
# [35/120] Saved road/road_034.jpg
# [36/120] Saved road/road_035.jpg
# [37/120] Saved road/road_036.jpg
# [38/120] Saved road/road_037.jpg
# [39/120] Saved road/road_038.jpg
# [40/120] Saved road/road_039.jpg
# [41/120] Saved road/road_040.jpg
# [42/120] Saved road/road_041.jpg
# [43/120] Saved road/road_042.jpg
# [44/120] Saved road/road_043.jpg
# [45/120] Saved road/road_044.jpg
# [46/120] Saved road/road_045.jpg
# [47/120] Saved road/road_046.jpg
# [48/120] Saved road/road_047.jpg
# [49/120] Saved road/road_048.jpg
# [50/120] Saved road/road_049.jpg
# [51/120] Saved road/road_050.jpg
# [52/120] Saved road/road_051.jpg
# [53/120] Saved road/road_052.jpg
# [54/120] Saved road/road_053.jpg
# [55/120] Saved road/road_054.jpg
# [56/120] Saved road/road_055.jpg
# [57/120] Saved road/road_056.jpg
# [58/120] Saved road/road_057.jpg
# [59/120] Saved road/road_058.jpg
# [60/120] Saved road/road_059.jpg
# [61/120] Saved road/road_060.jpg
# [62/120] Saved road/road_061.jpg
# [63/120] Saved road/road_062.jpg
# [64/120] Saved road/road_063.jpg
# [65/120] Saved road/road_064.jpg
# [66/120] Saved road/road_065.jpg
# [67/120] Saved road/road_066.jpg
# [68/120] Saved road/road_067.jpg
# [69/120] Saved road/road_068.jpg
# [70/120] Saved road/road_069.jpg
# [71/120] Saved road/road_070.jpg
# [72/120] Saved road/road_071.jpg
# [73/120] Saved road/road_072.jpg
# [74/120] Saved road/road_073.jpg
# [75/120] Saved road/road_074.jpg
# [76/120] Saved road/road_075.jpg
# [77/120] Saved road/road_076.jpg
# [78/120] Saved road/road_077.jpg
# [79/120] Saved road/road_078.jpg
# [80/120] Saved road/road_079.jpg
# [81/120] Saved road/road_080.jpg
# [82/120] Saved road/road_081.jpg
# [83/120] Saved road/road_082.jpg
# [84/120] Saved road/road_083.jpg
# [85/120] Saved road/road_084.jpg
# [86/120] Saved road/road_085.jpg
# [87/120] Saved road/road_086.jpg
# [88/120] Saved road/road_087.jpg
# [89/120] Saved road/road_088.jpg
# [90/120] Saved road/road_089.jpg
# [91/120] Saved road/road_090.jpg
# [92/120] Saved road/road_091.jpg
# [93/120] Saved road/road_092.jpg
# [94/120] Saved road/road_093.jpg
# [95/120] Saved road/road_094.jpg
# [96/120] Saved road/road_095.jpg
# [97/120] Saved road/road_096.jpg
# [98/120] Saved road/road_097.jpg
# [99/120] Saved road/road_098.jpg
# [100/120] Saved road/road_099.jpg
# [101/120] Saved road/road_100.jpg
# [102/120] Saved road/road_101.jpg
# [103/120] Saved road/road_102.jpg
# [104/120] Saved road/road_103.jpg
# [105/120] Saved road/road_104.jpg
# [106/120] Saved road/road_105.jpg
# [107/120] Saved road/road_106.jpg
# [108/120] Saved road/road_107.jpg
# [109/120] Saved road/road_108.jpg
# [110/120] Saved road/road_109.jpg
# [111/120] Saved road/road_110.jpg
# [112/120] Saved road/road_111.jpg
# [113/120] Saved road/road_112.jpg
# [114/120] Saved road/road_113.jpg
# [115/120] Saved road/road_114.jpg
# [116/120] Saved road/road_115.jpg
# [117/120] Saved road/road_116.jpg
# [118/120] Saved road/road_117.jpg
# [119/120] Saved road/road_118.jpg
# [120/120] Saved road/road_119.jpg
# Auto capture completed.

# %%
# Cleanly release resources
import gc

camera.running = False
camera.cap.release()
del camera

gc.collect()
# Out:
# Exception in thread Thread-4:
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.6/threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/jetcam-0.0.0-py3.6.egg/jetcam/camera.py", line 34, in _capture_frames
#     self.value = self._read()
#   File "/usr/local/lib/python3.6/dist-packages/jetcam-0.0.0-py3.6.egg/jetcam/csi_camera.py", line 40, in _read
#     raise RuntimeError('Could not read image from camera')
# RuntimeError: Could not read image from camera
# 20
